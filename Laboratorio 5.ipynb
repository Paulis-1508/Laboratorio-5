# %% [markdown]
# **Laboratorio 5**
#
# María Paula Angulo Collantes
#
# Danna Gabriela Castro

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("anage_animalia.csv")

# %% [markdown]
# **Punto 1**

# %%
df.shape
# Out:
# (4513, 31)

# %%
df.dtypes
# Out:
# HAGRID                                int64
# Kingdom                                 str
# Phylum                                  str
# Class                                   str
# Order                                   str
# Family                                  str
# Genus                                   str
# Species                                 str
# Common name                             str
# Female maturity (days)              float64
# Male maturity (days)                float64
# Gestation/Incubation (days)         float64
# Weaning (days)                      float64
# Litter/Clutch size                  float64
# Litters/Clutches per year           float64
# Inter-litter/Interbirth interval    float64
# Birth weight (g)                    float64
# Weaning weight (g)                  float64
# Adult weight (g)                    float64
# Growth rate (1/days)                float64
# Maximum longevity (yrs)             float64
# Source                                  str
# Specimen origin                         str
# Sample size                             str
# Data quality                            str
# IMR (per yr)                        float64
# MRDT (yrs)                          float64
# Metabolic rate (W)                  float64
# Body mass (g)                       float64
# Temperature (K)                     float64
# References                              str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4513 entries, 0 to 4512
# Data columns (total 31 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   HAGRID                            4513 non-null   int64
#  1   Kingdom                           4513 non-null   str
#  2   Phylum                            4513 non-null   str
#  3   Class                             4513 non-null   str
#  4   Order                             4513 non-null   str
#  5   Family                            4513 non-null   str
#  6   Genus                             4513 non-null   str
#  7   Species                           4513 non-null   str
#  8   Common name                       4513 non-null   str
#  9   Female maturity (days)            2459 non-null   float64
#  10  Male maturity (days)              1880 non-null   float64
#  11  Gestation/Incubation (days)       1833 non-null   float64
#  12  Weaning (days)                    768 non-null    float64
#  13  Litter/Clutch size                2091 non-null   float64
#  14  Litters/Clutches per year         1304 non-null   float64
#  15  Inter-litter/Interbirth interval  765 non-null    float64
#  16  Birth weight (g)                  1230 non-null   float64
#  17  Weaning weight (g)                384 non-null    float64
#  18  Adult weight (g)                  3641 non-null   float64
#  19  Growth rate (1/days)              559 non-null    float64
#  20  Maximum longevity (yrs)           4025 non-null   float64
#  21  Source                            3959 non-null   str
#  22  Specimen origin                   4513 non-null   str
#  23  Sample size                       4513 non-null   str
#  24  Data quality                      4513 non-null   str
#  25  IMR (per yr)                      40 non-null     float64
#  26  MRDT (yrs)                        36 non-null     float64
#  27  Metabolic rate (W)                627 non-null    float64
#  28  Body mass (g)                     627 non-null    float64
#  29  Temperature (K)                   494 non-null    float64
#  30  References                        4512 non-null   str
# dtypes: float64(17), int64(1), str(13)
# memory usage: 1.1 MB

# %%
df.isnull().sum()
# Out:
# HAGRID                                 0
# Kingdom                                0
# Phylum                                 0
# Class                                  0
# Order                                  0
# Family                                 0
# Genus                                  0
# Species                                0
# Common name                            0
# Female maturity (days)              2054
# Male maturity (days)                2633
# Gestation/Incubation (days)         2680
# Weaning (days)                      3745
# Litter/Clutch size                  2422
# Litters/Clutches per year           3209
# Inter-litter/Interbirth interval    3748
# Birth weight (g)                    3283
# Weaning weight (g)                  4129
# Adult weight (g)                     872
# Growth rate (1/days)                3954
# Maximum longevity (yrs)              488
# Source                               554
# Specimen origin                        0
# Sample size                            0
# Data quality                           0
# IMR (per yr)                        4473
# MRDT (yrs)                          4477
# Metabolic rate (W)                  3886
# Body mass (g)                       3886
# Temperature (K)                     4019
# References                             1
# dtype: int64

# %%
df.isnull().mean() * 100
# Out:
# HAGRID                               0.000000
# Kingdom                              0.000000
# Phylum                               0.000000
# Class                                0.000000
# Order                                0.000000
# Family                               0.000000
# Genus                                0.000000
# Species                              0.000000
# Common name                          0.000000
# Female maturity (days)              45.512963
# Male maturity (days)                58.342566
# Gestation/Incubation (days)         59.384002
# Weaning (days)                      82.982495
# Litter/Clutch size                  53.667184
# Litters/Clutches per year           71.105695
# Inter-litter/Interbirth interval    83.048970
# Birth weight (g)                    72.745402
# Weaning weight (g)                  91.491248
# Adult weight (g)                    19.321959
# Growth rate (1/days)                87.613561
# Maximum longevity (yrs)             10.813206
# Source                              12.275648
# Specimen origin                      0.000000
# Sample size                          0.000000
# Data quality                         0.000000
# IMR (per yr)                        99.113672
# MRDT (yrs)                          99.202304
# Metabolic rate (W)                  86.106803
# Body mass (g)                       86.106803
# Temperature (K)                     89.053844
# References                           0.022158
# dtype: float64

# %%
df["Data quality"].value_counts()
# Out:
# Data quality
# acceptable      3816
# low              488
# high             108
# questionable     101
# Name: count, dtype: int64

# %%
df["Specimen origin"].value_counts()
# Out:
# Specimen origin
# wild         2008
# captivity    1902
# unknown       603
# Name: count, dtype: int64
